# %% [markdown]
# **Emotion Detection**

# %% [markdown]
# *Importing Libraries*

# %%
import matplotlib.pyplot as plt
from glob import glob
import cv2
import random
import os
# %matplotlib inline

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Input, Dropout, Flatten, Conv2D
from tensorflow.keras.layers import BatchNormalization, Activation, MaxPooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.utils import plot_model

from IPython.display import SVG, Image
import tensorflow as tf
print("Tensorflow version:", tf.__version__)
# Out:
# Tensorflow version: 2.19.0

# %% [markdown]
# *Exploring Dataset*

# %%
images = glob("train/**/**")
for i in range(9):
    image = random.choice(images)
    plt.figure(figsize=(12,12))
    plt.subplot(331+i)
    plt.imshow(cv2.imread(image));plt.axis('off')

# %% [markdown]
# *Preparing Data for Training*

# %%
img_size = 48
batch_size = 64

datagen_train = ImageDataGenerator(
    rescale=1./255,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)

datagen_validation = ImageDataGenerator(rescale=1./255)

train_generator = datagen_train.flow_from_directory(
    "train/",
    target_size=(img_size, img_size),
    color_mode="grayscale",
    batch_size=batch_size,
    class_mode="categorical",
    shuffle=True
)

validation_generator = datagen_validation.flow_from_directory(
    "test/",
    target_size=(img_size, img_size),
    color_mode="grayscale",
    batch_size=batch_size,
    class_mode="categorical",
    shuffle=True
)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# *Defining Model*

# %%
def Convolution(input_tensor, filters, kernel_size):
    x = Conv2D(filters = filters, kernel_size = kernel_size, padding = "same")(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size = (2,2))(x)
    x = Dropout(0.25)(x)
    
    return x

# %%
def Dense_f(input_tensor, nodes):
    x = Dense(nodes)(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.25)(x)
    
    return x

# %%
def model_fer(input_shape):
    inputs = Input(input_shape)
    conv_1 = Convolution(inputs,64,(3,3))
    conv_2 = Convolution(conv_1,128,(5,5))
    conv_3 = Convolution(conv_2,512,(3,3))
    conv_4 = Convolution(conv_3,512,(3,3))

    flatten = Flatten()(conv_4)
    
    dense_1 = Dense_f(flatten,256)
    dense_2 = Dense_f(dense_1,512)

    output  = Dense(7, activation="softmax")(dense_2)
    model  =  Model(inputs=[inputs],outputs = [output])
    opt = Adam(learning_rate=0.0005)
    
    model.compile(loss=['categorical_crossentropy'] , optimizer = opt , metrics =["accuracy"])

    return model

# %%
model = model_fer((48,48,1))
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 48, 48, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 48, 48, 64)          │             640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 48, 48, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation (Activation)              │ (None, 48, 48, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 24, 24, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 24, 24, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 24, 24, 128)         │         204,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 24, 24, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_1 (Activation)            │ (None, 24, 24, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 12, 12, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 12, 12, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 12, 12, 512)         │         590,336 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 12, 12, 512)         │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_2 (Activation)            │ (None, 12, 12, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 6, 6, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 6, 6, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 6, 6, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 6, 6, 512)           │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_3 (Activation)            │ (None, 6, 6, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 3, 3, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 3, 3, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 4608)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │       1,179,904 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_4 (Activation)            │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 512)                 │         131,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_5 (Activation)            │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 7)                   │           3,591 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,478,727 (17.08 MB)
#  Trainable params: 4,474,759 (17.07 MB)
#  Non-trainable params: 3,968 (15.50 KB)

# %% [markdown]
# *Initializing the Model*

# %%
epochs = 30
steps_per_epoch = train_generator.n//train_generator.batch_size
validation_steps = validation_generator.n//validation_generator.batch_size

checkpoint = ModelCheckpoint("model.weights.h5", monitor  ='val_accuracy', save_weights_only = True, mode = 'max', verbose =1)
reducing_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, min_lr=0.00001)
callbacks = [checkpoint,reducing_lr]

# %% [markdown]
# **Traning the Model**

# %% [markdown]
# *The next cell takes time to complete*

# %%
history = model.fit(
x = train_generator,
steps_per_epoch = steps_per_epoch,
epochs = epochs,
validation_data = validation_generator,
validation_steps = validation_steps,
callbacks = callbacks)
# Out:
# C:\GPU_Environment\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# C:\GPU_Environment\Lib\site-packages\keras\src\models\functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor']
# Received: inputs=Tensor(shape=(None, 48, 48, 1))
#   warnings.warn(msg)
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.2627 - loss: 1.9341
# Epoch 1: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1094s 2s/step - accuracy: 0.2628 - loss: 1.9338 - val_accuracy: 0.3500 - val_loss: 1.8146 - learning_rate: 5.0000e-04
# Epoch 2/30
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 9:42 1s/step - accuracy: 0.3125 - loss: 1.6211
# C:\GPU_Environment\Lib\site-packages\keras\src\trainers\epoch_iterator.py:107: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 2: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 45s 99ms/step - accuracy: 0.3125 - loss: 1.6211 - val_accuracy: 0.3640 - val_loss: 1.7721 - learning_rate: 5.0000e-04
# Epoch 3/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4218 - loss: 1.5072
# Epoch 3: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 621s 1s/step - accuracy: 0.4219 - loss: 1.5071 - val_accuracy: 0.4681 - val_loss: 1.3655 - learning_rate: 5.0000e-04
# Epoch 4/30
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 9:58 1s/step - accuracy: 0.3750 - loss: 1.4322
# Epoch 4: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 46s 100ms/step - accuracy: 0.3750 - loss: 1.4322 - val_accuracy: 0.4681 - val_loss: 1.3660 - learning_rate: 5.0000e-04
# Epoch 5/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4816 - loss: 1.3348
# Epoch 5: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 593s 1s/step - accuracy: 0.4816 - loss: 1.3347 - val_accuracy: 0.5372 - val_loss: 1.2049 - learning_rate: 5.0000e-04
# Epoch 6/30
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 9:07 1s/step - accuracy: 0.6562 - loss: 1.0596
# Epoch 6: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 43s 94ms/step - accuracy: 0.6562 - loss: 1.0596 - val_accuracy: 0.5381 - val_loss: 1.2096 - learning_rate: 5.0000e-04
# Epoch 7/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5333 - loss: 1.2260
# Epoch 7: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 584s 1s/step - accuracy: 0.5333 - loss: 1.2260 - val_accuracy: 0.5128 - val_loss: 1.2770 - learning_rate: 5.0000e-04
# Epoch 8/30
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 9:15 1s/step - accuracy: 0.6406 - loss: 1.0051
# Epoch 8: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 43s 94ms/step - accuracy: 0.6406 - loss: 1.0051 - val_accuracy: 0.5179 - val_loss: 1.2767 - learning_rate: 5.0000e-04
# Epoch 9/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5657 - loss: 1.1347
# Epoch 9: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 490s 1s/step - accuracy: 0.5657 - loss: 1.1346 - val_accuracy: 0.5823 - val_loss: 1.0915 - learning_rate: 5.0000e-05
# Epoch 10/30
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:17 1s/step - accuracy: 0.6094 - loss: 1.0954
# Epoch 10: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 32s 70ms/step - accuracy: 0.6094 - loss: 1.0954 - val_accuracy: 0.5823 - val_loss: 1.0925 - learning_rate: 5.0000e-05
# Epoch 11/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5783 - loss: 1.0976
# Epoch 11: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 479s 1s/step - accuracy: 0.5783 - loss: 1.0975 - val_accuracy: 0.5801 - val_loss: 1.0933 - learning_rate: 5.0000e-05
# Epoch 12/30
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 7:26 999ms/step - accuracy: 0.6406 - loss: 1.1642
# Epoch 12: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 32s 69ms/step - accuracy: 0.6406 - loss: 1.1642 - val_accuracy: 0.5802 - val_loss: 1.0930 - learning_rate: 5.0000e-05
# Epoch 13/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 998ms/step - accuracy: 0.5896 - loss: 1.0769
# Epoch 13: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 477s 1s/step - accuracy: 0.5896 - loss: 1.0769 - val_accuracy: 0.5900 - val_loss: 1.0790 - learning_rate: 1.0000e-05
# Epoch 14/30
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 9:07 1s/step - accuracy: 0.5781 - loss: 1.1645
# Epoch 14: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 33s 72ms/step - accuracy: 0.5781 - loss: 1.1645 - val_accuracy: 0.5901 - val_loss: 1.0799 - learning_rate: 1.0000e-05
# Epoch 15/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5907 - loss: 1.0689
# Epoch 15: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 530s 1s/step - accuracy: 0.5907 - loss: 1.0689 - val_accuracy: 0.5900 - val_loss: 1.0752 - learning_rate: 1.0000e-05
# Epoch 16/30
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 6:12 833ms/step - accuracy: 0.6562 - loss: 0.9333
# Epoch 16: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 31s 69ms/step - accuracy: 0.6562 - loss: 0.9333 - val_accuracy: 0.5901 - val_loss: 1.0752 - learning_rate: 1.0000e-05
# Epoch 17/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5996 - loss: 1.0539
# Epoch 17: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 484s 1s/step - accuracy: 0.5996 - loss: 1.0539 - val_accuracy: 0.5925 - val_loss: 1.0731 - learning_rate: 1.0000e-05
# Epoch 18/30
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 7:19 983ms/step - accuracy: 0.6250 - loss: 1.0325
# Epoch 18: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 33s 71ms/step - accuracy: 0.6250 - loss: 1.0325 - val_accuracy: 0.5919 - val_loss: 1.0730 - learning_rate: 1.0000e-05
# Epoch 19/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6044 - loss: 1.0514
# Epoch 19: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 482s 1s/step - accuracy: 0.6044 - loss: 1.0514 - val_accuracy: 0.5921 - val_loss: 1.0704 - learning_rate: 1.0000e-05
# Epoch 20/30
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 6:49 916ms/step - accuracy: 0.5938 - loss: 0.9908
# Epoch 20: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 32s 69ms/step - accuracy: 0.5938 - loss: 0.9908 - val_accuracy: 0.5925 - val_loss: 1.0696 - learning_rate: 1.0000e-05
# Epoch 21/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5971 - loss: 1.0638
# Epoch 21: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 498s 1s/step - accuracy: 0.5971 - loss: 1.0637 - val_accuracy: 0.5939 - val_loss: 1.0697 - learning_rate: 1.0000e-05
# Epoch 22/30
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 7:38 1s/step - accuracy: 0.5000 - loss: 1.3205
# Epoch 22: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 32s 69ms/step - accuracy: 0.5000 - loss: 1.3205 - val_accuracy: 0.5943 - val_loss: 1.0688 - learning_rate: 1.0000e-05
# Epoch 23/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5975 - loss: 1.0539
# Epoch 23: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 489s 1s/step - accuracy: 0.5975 - loss: 1.0539 - val_accuracy: 0.5953 - val_loss: 1.0689 - learning_rate: 1.0000e-05
# Epoch 24/30
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 7:56 1s/step - accuracy: 0.5625 - loss: 1.0892
# Epoch 24: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 35s 75ms/step - accuracy: 0.5625 - loss: 1.0892 - val_accuracy: 0.5940 - val_loss: 1.0698 - learning_rate: 1.0000e-05
# Epoch 25/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6012 - loss: 1.0490
# Epoch 25: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 490s 1s/step - accuracy: 0.6012 - loss: 1.0490 - val_accuracy: 0.5947 - val_loss: 1.0678 - learning_rate: 1.0000e-05
# Epoch 26/30
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 7:53 1s/step - accuracy: 0.6875 - loss: 1.0116
# Epoch 26: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 31s 68ms/step - accuracy: 0.6875 - loss: 1.0116 - val_accuracy: 0.5940 - val_loss: 1.0682 - learning_rate: 1.0000e-05
# Epoch 27/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5992 - loss: 1.0495
# Epoch 27: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 486s 1s/step - accuracy: 0.5992 - loss: 1.0495 - val_accuracy: 0.5953 - val_loss: 1.0666 - learning_rate: 1.0000e-05
# Epoch 28/30
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 7:52 1s/step - accuracy: 0.6719 - loss: 1.0064
# Epoch 28: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 32s 70ms/step - accuracy: 0.6719 - loss: 1.0064 - val_accuracy: 0.5958 - val_loss: 1.0660 - learning_rate: 1.0000e-05
# Epoch 29/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6006 - loss: 1.0508
# Epoch 29: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 560s 1s/step - accuracy: 0.6006 - loss: 1.0508 - val_accuracy: 0.5982 - val_loss: 1.0605 - learning_rate: 1.0000e-05
# Epoch 30/30
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 9:00 1s/step - accuracy: 0.4688 - loss: 1.2768
# Epoch 30: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 41s 89ms/step - accuracy: 0.4688 - loss: 1.2768 - val_accuracy: 0.5992 - val_loss: 1.0591 - learning_rate: 1.0000e-05

# %% [markdown]
# *Model Evaluation*

# %%
model.evaluate(validation_generator)
# Out:
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 41s 360ms/step - accuracy: 0.5963 - loss: 1.0710
# [1.0598974227905273, 0.5989133715629578]

# %% [markdown]
# *Plotting Loss*

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.legend(['Train','Validation'],loc = 'upper left')
plt.subplots_adjust(top=1.0,bottom=0.0,right =0.95,left=0.0,hspace=0.25,wspace=0.35)

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.legend(['Train','Validation'],loc = 'upper left')
plt.subplots_adjust(top=1.0,bottom=0.0,right =0.95,left=0.0,hspace=0.25,wspace=0.35)

# %% [markdown]
# *Saving Model*

# %%
model.save("emotion_model.h5")
